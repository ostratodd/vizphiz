# %%
import pdb
from Bio.Phylo.TreeConstruction import DistanceCalculator
from Bio.Phylo.TreeConstruction import DistanceTreeConstructor
from numpy import array
from Bio import SeqIO
from Bio import AlignIO
from Bio import Phylo
import matplotlib 
import matplotlib.pyplot as plt

# %%
aln = AlignIO.read(open('rod_aligned_db_fmt.fasta'),'fasta')

calculator = DistanceCalculator('blosum62')

#file1 = open('opsin_wds_distance_matrix.txt', 'w')

dm = (str(calculator.get_distance(aln)))

constructor = DistanceTreeConstructor(calculator)

phylo_tree = constructor.build_tree(aln)
phylo_tree.rooted = True

Phylo.write(phylo_tree, "wtopsin_phylo_sub.xml", "phyloxml")
Phylo.write(phylo_tree, "wtopsin_phylo.tre", "newick")

#Phylo.convert("wtopsin_phylo_sub.xml", "phyloxml", "wtopsin_phylo_sub.nex", "nexus")
#Phylo.convert("wtopsin_phylo_sub.xml", "phyloxml", "wtopsin_phylo.nhx", "newick")

#fig = Phylo.draw(phylo_tree)
#print(fig)
# Out:
# None

# %%
# Out:
# 1
